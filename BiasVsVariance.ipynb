# %% [markdown]
# <a href="https://colab.research.google.com/github/bvdsb01/mLearning/blob/main/BiasVsVariance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Bias vs Variance Tradeoff**

# %% [markdown]
# Variance and bias should be both low when training the model, to accurately represent the pattern in our data - and design a nice/good model.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We always try to train the balanced fit model - as that gives best performance.

# %% [markdown]
# Based on training samples selected, test dataset error varies
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Below line covering all the training points is an example of **Overfit Model**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Whenever there is talk of high variance, think of test error.**

# %% [markdown]
# **Overfitting happens when -**
#
# Train Error is close to zero
#
# Test error kaafi vary karti hai
#
# And generally when there is overfitting, there is high variance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Training DataSet ki error jyada aati hai - **underfit model**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Bias** is a measure of how accurately a model can capture a pattern in a training dataset. In above case since train error is big it is said to have a high bias.

# %% [markdown]
# In below image, the line more accurately captures the pattern of the points.

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Whenever thinking of bias, think of *train error***

# %% [markdown]
# Train error jyada is high bias
#
# Train error kam is low bias

# %% [markdown]
# **Balanced Fit Model**
# *   Bias = Low
# *   Variance = Low
#
# **Underfit Model**
# *  Bias = High
#
# **Overfit Model**
# *   Variance = High

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Data Scientist work is to train a model with low variance and low bias

# %% [markdown]
# #Ways to get balanced fit model

# %% [markdown]
# *Cross Validation
#
# *Regularization
#
# *Dimensionality Reduction
#
# *Ensemble Techniques - Bagging, Boosting
